# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime

tickers = ['^GSPC', 'NDAQ', 'BTC-USD', 'ETH-USD']
start = datetime.datetime(2015,1,1)
end = datetime.date.today()
stocks = yf.download(tickers, start=start,end = end, interval='1d')['Close']
stocks
# Out:
# [*********************100%***********************]  4 of 4 completed
#                  BTC-USD      ETH-USD        NDAQ        ^GSPC
# Date
# 2015-01-01    314.248993          NaN         NaN          NaN
# 2015-01-02    315.032013          NaN   47.860001  2058.199951
# 2015-01-03    281.082001          NaN         NaN          NaN
# 2015-01-04    264.195007          NaN         NaN          NaN
# 2015-01-05    274.473999          NaN   47.610001  2020.579956
# ...                  ...          ...         ...          ...
# 2021-12-04  49200.703125  4119.587402         NaN          NaN
# 2021-12-05  49368.847656  4198.322754         NaN          NaN
# 2021-12-06  50582.625000  4358.737305  197.979996  4591.669922
# 2021-12-07  50700.085938  4315.061523  205.550003  4686.750000
# 2021-12-08  50247.460938  4334.821777         NaN          NaN
#
# [2534 rows x 4 columns]

# %%
stocks = stocks.rename(columns={'^GSPC': 'S&P 500', 'NDAQ': 'NASDAQ', 'BTC-USD': 'Bitcoin', 'ETH-USD': 'Ethereum'})
stocks.plot(figsize=(20,10), logy=True)
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
stocks.plot(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
import time
from IPython import display
import pylab as pl
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime
from dateutil import tz

# %matplotlib inline
plt.figure(figsize=(20,10))
to_zone = tz.gettz('America/New_York')
while True:
    tickers = ['BTC-USD']
    start = datetime.datetime(2020, 10, 1)
    end = datetime.datetime.now()
    btc = yf.download(tickers, start=start,end = end, interval='1h')['Close']
    now = btc.index[-1].astimezone(to_zone)
    plt.title(f'{now}: ${round(btc.values[-1], 2):,}')
    pl.plot(btc)
    display.clear_output(wait=True)
    display.display(pl.gcf())
    time.sleep(60)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15052/3033506502.py in <module>
#      22     display.clear_output(wait=True)
#      23     display.display(pl.gcf())
# ---> 24     time.sleep(60)
#
# KeyboardInterrupt:
