# %% [markdown]
# # Stock Price Crash

# %% [markdown]
# Stock price crash provides a signal for investors and risk managers about the weakness and strength of a company’s corporate governance. Corporate governance is defined as the way corporations are directed and controlled, as well as the ways they are or are not “promoting corporate fairness, transparency, and accountability” (Wolfensohn 1999).

# %% [markdown]
# Following this definition, corporate governance has three pillars:
#
# **Fairness**
# This principle refers to equal treatment of all shareholders.
#
# **Transparency**
# Informing shareholders about any company events in a timely manner is called transparency. This implies the opposite of opaqueness, or a company’s unwillingness to disclose information to shareholders.
#
# **Accountability**
# This is related to setting a well-established code of conduct by which a fair, balanced, and understandable assessment of a company’s position is presented to shareholders.

# %% [markdown]
# CRSP has provided data for academic research and to support classroom instructions since 1960. CRSP has high-quality data in finance, economics, and related fields. For more information see the CRSP website (https://oreil.ly/oO3X8).

# %% [markdown]
# Similarly, the Compustat database has provided financial, economic, and market information about global companies since 1962. It is a product of S&P Global Market Intelligence. For more information see Compustat Brochure (https://oreil.ly/E4Hpj).

# %% [markdown]
# The literature about stock price crash has been growing and different crash measures are employed by different researchers. Before introducing ML-based crash measures, it is worth comparing the pros and cons of these differing approaches.
#
# The main crash measures used in the literature are:
#
# * Down-to-up volatility (DUVOL)
# * Negative coefficient of skewness (NCSKEW)
# * CRASH

# %% [markdown]
# \begin{equation}
# \text{DUVOL}=log\{\frac{(n_{u-1})\sum_{\text{down}} R^2_{it}}{(n_{d-1})\sum_{\text{up}} R^2_{it}}\}
# \end{equation}

# %% [markdown]
# \begin{equation}
# \text{NCSKEW} = - \frac{(n(n-1)^{3/2}\sum R^3_{it})}{((n-1)(n-2)(\sum R^2_{it})^{3/2})}
# \end{equation}

# %% [markdown]
# CRASH is a binary variable which takes the value 1 if, in that week, the return is 3.09 standard deviations below the yearly mean return and 0 if it is above that threshold.

# %% [markdown]
# ## Minimum Covariance Determinant

# %% [markdown]
# The algorithm of MCD can be given as follows:
#
# 1.	Detect initial robust clustering based on the data.
# 2.	Calculate mean vector $M^a$ and positive definite covariance matrix $\sum^a$ for each cluster.
# 3.	Compute MCD, for each observation in the cluster.
# 4.	Assign a new observation with smaller MCD to the cluster.
# 5.	Select half sample h based on smallest MCD and compute $M^a$ and $ \sum^a$ from h.
# 6.	Repeat 2-5 until there is no room for change in h.
# 7.	Detect outlier if
# $ c_p=\sqrt{\chi^2_{p,0.95}} $  is less than $d^2$.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns; sns.set()
pd.set_option('use_inf_as_na', True)
import warnings
warnings.filterwarnings('ignore')
plt.rcParams['figure.dpi'] = 300
plt.rcParams['savefig.dpi'] = 300

# %%
crash_data = pd.read_csv('crash_data.csv')

# %%
crash_data.head()
# Out:
#    Unnamed: 0       RET      date TICKER    vwretx  BIDLO   ASKHI    PRC  \
# 0    27882462  0.041833  20100104    BAC  0.017045  15.12  15.750  15.69
# 1    27882463  0.032505  20100105    BAC  0.003362  15.70  16.210  16.20
# 2    27882464  0.011728  20100106    BAC  0.001769  16.03  16.540  16.39
# 3    27882465  0.032947  20100107    BAC  0.002821  16.51  17.185  16.93
# 4    27882466 -0.008860  20100108    BAC  0.004161  16.63  17.100  16.78
#
#            VOL
# 0  180845100.0
# 1  209521200.0
# 2  205257900.0
# 3  320868400.0
# 4  220104600.0

# %%
crash_data.date = pd.to_datetime(crash_data.date, format='%Y%m%d')
crash_data = crash_data.set_index('date')

# %%
crash_dataw = crash_data.groupby('TICKER').resample('W').\
              agg({'RET':'mean', 'vwretx':'mean', 'VOL':'mean',
                   'BIDLO':'mean', 'ASKHI':'mean', 'PRC':'mean'})

# %%
crash_dataw = crash_dataw.reset_index()
crash_dataw.dropna(inplace=True)
stocks = crash_dataw.TICKER.unique()

# %%
crash_dataw
# Out:
#       TICKER       date       RET    vwretx         VOL       BIDLO  \
# 0       AAPL 2010-01-10  0.001235  0.005832  18980442.8  210.898000
# 1       AAPL 2010-01-17 -0.005719 -0.002080  19772230.6  206.772002
# 2       AAPL 2010-01-24 -0.009510 -0.009480  25930885.0  205.277505
# 3       AAPL 2010-01-31 -0.005426 -0.003738  52020594.0  198.250202
# 4       AAPL 2010-02-07  0.003722 -0.001463  26953208.4  192.304004
# ...      ...        ...       ...       ...         ...         ...
# 13398    XOM 2019-12-08  0.004058  0.000184  12371989.0   68.199000
# 13399    XOM 2019-12-15 -0.000734  0.001344  13958017.0   68.882000
# 13400    XOM 2019-12-22  0.002067  0.003199  18338291.4   69.384000
# 13401    XOM 2019-12-29 -0.000172  0.001220   9378504.5   69.832525
# 13402    XOM 2020-01-05 -0.000774 -0.001213  12924639.0   69.205000
#
#             ASKHI         PRC
# 0      213.864000  212.383998
# 1      211.152002  208.767994
# 2      212.888450  208.146752
# 3      207.338002  201.650398
# 4      197.378002  195.466002
# ...           ...         ...
# 13398   68.946000   68.574000
# 13399   70.160000   69.450000
# 13400   70.239340   69.776000
# 13401   70.403075   70.082500
# 13402   70.117500   69.630000
#
# [13402 rows x 8 columns]

# %%
#crash_dataw2 = pd.DataFrame()
#for i in stocks[: 10]:
#    crash_dataw2 =crash_dataw2.append(crash_dataw[crash_dataw.TICKER == i])

# %%
#crash_dataw = crash_dataw2.copy()

# %%
plt.figure(figsize=(12, 8))
k = 1

for i in stocks[: 4]:
    plt.subplot(2, 2, k)
    plt.hist(crash_dataw[crash_dataw.TICKER == i]['RET'])
    plt.title('Histogram of '+i)
    k+=1
plt.show()

# %% [markdown]
# ## Firm-specific return

# %%
X = crash_dataw.loc[crash_dataw['TICKER'] == i]['vwretx'].values
X
# Out:
# array([ 5.83160000e-03, -2.08000000e-03, -9.47950000e-03, -3.73800000e-03,
#        -1.46340000e-03,  2.97040000e-03,  7.69975000e-03, -9.91000000e-04,
#         7.06140000e-03,  2.30060000e-03,  9.24400000e-04,  9.84600000e-04,
#         3.16275000e-03,  3.09360000e-03, -2.67600000e-04,  4.48580000e-03,
#        -5.06980000e-03, -1.41056000e-02,  5.87300000e-03, -9.37940000e-03,
#         1.52680000e-03, -5.82050000e-03,  5.29780000e-03,  5.00540000e-03,
#        -6.77940000e-03, -1.08320000e-02,  1.30712500e-02, -2.61320000e-03,
#         7.47920000e-03,  4.44000000e-05,  3.26600000e-03, -8.10960000e-03,
#        -5.60200000e-04, -6.54000000e-04,  7.42080000e-03,  5.70000000e-04,
#         3.10380000e-03,  3.97760000e-03,  5.47600000e-04,  3.34100000e-03,
#         1.78680000e-03,  2.96920000e-03, -1.49525000e-03,  3.02980000e-03,
#         4.71800000e-04,  1.55640000e-03,  2.22360000e-03,  3.73200000e-04,
#         1.13940000e-03,  1.94600000e-04,  4.31600000e-04, -5.64400000e-04,
#         1.03400000e-04,  2.57450000e-03,  2.40860000e-03,  2.84000000e-04,
#         1.45480000e-03,  1.00660000e-03, -5.11500000e-04,  5.99675000e-03,
#         3.06180000e-03,  1.86675000e-03,  3.85100000e-03, -7.70780000e-03,
#        -9.96900000e-03,  8.27020000e-03,  9.93500000e-04, -3.81660000e-03,
#         6.74440000e-03, -2.23340000e-03, -1.09304000e-02,  4.53150000e-03,
#        -2.46120000e-03,  3.78140000e-03,  1.38580000e-03, -2.93600000e-04,
#        -2.07600000e-04,  4.53740000e-03, -5.52000000e-04,  3.17600000e-04,
#         1.45700000e-03,  3.10920000e-03,  6.90000000e-05, -1.42900000e-03,
#        -2.88680000e-03,  3.95975000e-03,  2.38500000e-03,  1.75400000e-04,
#         3.88600000e-04,  1.38980000e-03, -2.73000000e-04,  8.35000000e-04,
#         2.06440000e-03,  1.48120000e-03, -3.11950000e-03,  2.22120000e-03,
#         1.33060000e-03, -1.26440000e-03, -2.89960000e-03, -8.26120000e-03,
#        -3.66000000e-05, -7.74020000e-03,  5.37360000e-03,  3.21740000e-03,
#        -2.86460000e-03, -8.53000000e-03,  8.37860000e-03, -1.09300000e-02,
#        -2.86620000e-03, -1.44850000e-02,  7.25875000e-03,  5.51750000e-03,
#         5.93800000e-03,  5.29040000e-03, -1.62500000e-04,  3.27340000e-03,
#        -2.62000000e-05,  5.05100000e-03,  1.74425000e-03,  6.01800000e-04,
#        -4.61440000e-03,  5.29900000e-03, -1.94840000e-03,  2.47660000e-03,
#         4.08000000e-03,  1.08600000e-03, -6.07500000e-04,  2.22200000e-03,
#         6.29600000e-04, -4.20240000e-03, -1.74040000e-03, -2.31940000e-03,
#        -6.26500000e-03,  7.91060000e-03,  7.99200000e-04,  4.21920000e-03,
#        -1.67000000e-04,  3.73175000e-03,  1.21060000e-03, -2.22160000e-03,
#         3.06320000e-03, -6.26580000e-03, -8.82000000e-04, -2.11340000e-03,
#        -2.72720000e-03,  5.05080000e-03,  3.93925000e-03,  2.27600000e-03,
#        -8.57200000e-04, -2.58760000e-03, -8.49200000e-04,  1.20120000e-03,
#         1.08920000e-03,  2.40200000e-03,  2.76020000e-03,  1.44640000e-03,
#         1.48400000e-03, -5.58400000e-04,  2.65575000e-03,  1.83600000e-04,
#         1.34380000e-03,  3.19900000e-03])

# %%
import statsmodels.api as sm
residuals = []

for i in stocks:
    Y = crash_dataw.loc[crash_dataw['TICKER'] == i]['RET'].values
    X = crash_dataw.loc[crash_dataw['TICKER'] == i]['vwretx'].values
    X = sm.add_constant(X)
    ols = sm.OLS(Y[2:-2], X[2:-2] + X[1:-3] + X[0:-4] + \
                 X[3:-1] + X[4:]).fit()
    residuals.append(ols.resid)

# %%
residuals = list(map(lambda x: np.log(1 + x), residuals))

# %%
crash_data_sliced = pd.DataFrame([])
for i in stocks:
    crash_data_sliced = crash_data_sliced.append(crash_dataw.loc[crash_dataw.TICKER == i]
                               [2:-2])
crash_data_sliced.head()
# Out:
#   TICKER       date       RET    vwretx          VOL       BIDLO       ASKHI  \
# 2   AAPL 2010-01-24 -0.009510 -0.009480  25930885.00  205.277505  212.888450
# 3   AAPL 2010-01-31 -0.005426 -0.003738  52020594.00  198.250202  207.338002
# 4   AAPL 2010-02-07  0.003722 -0.001463  26953208.40  192.304004  197.378002
# 5   AAPL 2010-02-14  0.005031  0.002970  19731018.60  194.513998  198.674002
# 6   AAPL 2010-02-21  0.001640  0.007700  16618997.25  201.102500  203.772500
#
#           PRC
# 2  208.146752
# 3  201.650398
# 4  195.466002
# 5  196.895200
# 6  202.636995

# %%
len(crash_data_sliced)
# Out:
# 13286

# %% [markdown]
# ## Elliptic Envelope

# %%
from sklearn.covariance import EllipticEnvelope
envelope = EllipticEnvelope(contamination=0.02, support_fraction=1)
ee_predictions = {}

for i, j in zip(range(len(stocks)), stocks):
    envelope.fit(np.array(residuals[i]).reshape(-1, 1))
    ee_predictions[j] = envelope.predict(np.array(residuals[i])
                                         .reshape(-1, 1))

# %%
transform = []

for i in stocks:
    for j in range(len(ee_predictions[i])):
        transform.append(np.where(ee_predictions[i][j] == 1, 0, -1))

# %%
crash_data_sliced = crash_data_sliced.reset_index()
crash_data_sliced['residuals'] = np.concatenate(residuals)
crash_data_sliced['neg_outliers'] = np.where((np.array(transform)) == -1, 1, 0)
crash_data_sliced.loc[(crash_data_sliced.neg_outliers == 1) &
                      (crash_data_sliced.residuals > 0),
                      'neg_outliers'] = 0

# %%
crash_data_sliced['neg_outliers'].value_counts()
# Out:
# 0    13155
# 1      131
# Name: neg_outliers, dtype: int64

# %%
plt.figure(figsize=(12, 8)) 
k=1

for i in stocks[8:12]:
    plt.subplot(2, 2, k)
    crash_data_sliced['residuals'][crash_data_sliced.TICKER == i]\
    .hist(label='normal', bins=30, color='gray')
    outliers = crash_data_sliced['residuals'][(crash_data_sliced.TICKER == i) &
    (crash_data_sliced.neg_outliers > 0)]
    outliers.hist(color='black', label='anomaly') 
    plt.title(i)
    plt.legend()
    k+=1

# %%
crash_data_sliced = crash_data_sliced.set_index('date')
crash_data_sliced.index = pd.to_datetime(crash_data_sliced.index)

# %%
std = crash_data.groupby('TICKER')['RET'].resample('W').std()\
      .reset_index()
crash_dataw['std'] = pd.DataFrame(std['RET'])

# %%
yearly_data = crash_data_sliced.groupby('TICKER')['residuals']\
              .resample('Y').agg({'residuals':{'mean', 'std'}})\
              .reset_index()
yearly_data.columns = ['TICKER', 'date', 'mean', 'std']
yearly_data.head()
# Out:
#   TICKER       date      mean       std
# 0   AAPL 2010-12-31  0.000686  0.008291
# 1   AAPL 2011-12-31  0.000431  0.009088
# 2   AAPL 2012-12-31 -0.000079  0.008056
# 3   AAPL 2013-12-31 -0.001019  0.009096
# 4   AAPL 2014-12-31  0.000468  0.006174

# %%
merge_crash = pd.merge(crash_data_sliced.reset_index(), yearly_data,
                       how='outer', on=['TICKER', 'date'])

# %%
merge_crash[['annual_mean', 'annual_std']] = merge_crash\
                                             .sort_values(by=['TICKER',
                                                              'date'])\
                                             .iloc[:, -2:]\
                                             .fillna(method='bfill')
merge_crash['residuals'] = merge_crash.sort_values(by=['TICKER',
                                                       'date'])\
                                                      ['residuals']\
                                             .fillna(method='ffill')
merge_crash = merge_crash.drop(merge_crash.iloc[: ,-4:-2], axis=1)

# %%
crash_risk_out = []

for j in stocks:
    for k in range(len(merge_crash[merge_crash.TICKER == j])):
        if merge_crash[merge_crash.TICKER == j]['residuals'].iloc[k] < \
        merge_crash[merge_crash.TICKER == j]['annual_mean'].iloc[k] - \
        3.09 * merge_crash[merge_crash.TICKER == j]['annual_std'].iloc[k]:
            crash_risk_out.append(1)
        else:
            crash_risk_out.append(0)

# %%
merge_crash['crash_risk'] = crash_risk_out
merge_crash['crash_risk'].value_counts()
# Out:
# 0    13476
# 1       44
# Name: crash_risk, dtype: int64

# %%
merge_crash = merge_crash.set_index('date')
merge_crash_annual = merge_crash.groupby('TICKER')\
                     .resample('1Y')['crash_risk'].sum().reset_index()

# %%
down = []

for j in range(len(merge_crash)):
    if merge_crash['residuals'].iloc[j] < \
       merge_crash['annual_mean'].iloc[j]:
        down.append(1)
    else:
        down.append(0)

# %%
merge_crash = merge_crash.reset_index()
merge_crash['down'] = pd.DataFrame(down)
merge_crash['up'] = 1 - merge_crash['down']
down_residuals = merge_crash[merge_crash.down == 1]\
                 [['residuals', 'TICKER', 'date']]
up_residuals = merge_crash[merge_crash.up == 1]\
               [['residuals', 'TICKER', 'date']]

# %%
down_residuals['residuals_down_sq'] = down_residuals['residuals'] ** 2
down_residuals['residuals_down_cubic'] = down_residuals['residuals'] **3
up_residuals['residuals_up_sq'] = up_residuals['residuals'] ** 2
up_residuals['residuals_up_cubic'] = up_residuals['residuals'] ** 3
down_residuals['down_residuals'] = down_residuals['residuals']
up_residuals['up_residuals'] = up_residuals['residuals']
del down_residuals['residuals']
del up_residuals['residuals']

# %%
merge_crash['residuals_sq'] = merge_crash['residuals'] ** 2
merge_crash['residuals_cubic'] = merge_crash['residuals'] ** 3

# %%
merge_crash_all = merge_crash.merge(down_residuals,
                                    on=['TICKER', 'date'],
                                    how='outer')
merge_crash_all = merge_crash_all.merge(up_residuals,
                                        on=['TICKER', 'date'],
                                        how='outer')

# %%
cols = ['BIDLO', 'ASKHI', 'residuals', 
        'annual_std', 'residuals_sq', 'residuals_cubic',
        'down', 'up', 'residuals_up_sq', 'residuals_down_sq',
        'neg_outliers']
merge_crash_all = merge_crash_all.set_index('date')
merge_grouped = merge_crash_all.groupby('TICKER')[cols]\
                .resample('1Y').sum().reset_index()
merge_grouped['neg_outliers'] = np.where(merge_grouped.neg_outliers >=
                                         1, 1, 0)

# %%
merge_grouped = merge_grouped.set_index('date')
merge_all = merge_grouped.groupby('TICKER')\
            .resample('1Y').agg({'down':['sum', 'count'],
                                 'up':['sum', 'count']})\
            .reset_index()
merge_all.head()
# Out:
#   TICKER       date down        up
#                      sum count sum count
# 0   AAPL 2010-12-31   27     1  23     1
# 1   AAPL 2011-12-31   26     1  27     1
# 2   AAPL 2012-12-31   28     1  26     1
# 3   AAPL 2013-12-31   24     1  29     1
# 4   AAPL 2014-12-31   22     1  31     1

# %%
merge_grouped['down'] = merge_all['down']['sum'].values
merge_grouped['up'] = merge_all['up']['sum'].values
merge_grouped['count'] = merge_grouped['down'] + merge_grouped['up']

# %%
merge_grouped = merge_grouped.reset_index()

# %%
merge_grouped['duvol'] = np.log(((merge_grouped['up'] - 1) * 
                                 merge_grouped['residuals_down_sq']) /
                                ((merge_grouped['down'] - 1) * 
                                 merge_grouped['residuals_up_sq']))# <1>

# %%
merge_grouped['duvol'].mean()
# Out:
# -0.023371498758114867

# %%
merge_grouped['ncskew'] = - (((merge_grouped['count'] * 
                               (merge_grouped['count'] - 1) **
                               (3 / 2)) * 
                             merge_grouped['residuals_cubic']) / 
                             (((merge_grouped['count'] - 1) * 
                               (merge_grouped['count'] - 2)) * 
                              merge_grouped['residuals_sq'] **
                              (3 / 2)))

# %%
merge_grouped['ncskew'].mean()
# Out:
# -0.031025284134663118

# %%
merge_grouped['crash_risk'] = merge_crash_annual['crash_risk']
merge_grouped['crash_risk'] = np.where(merge_grouped.crash_risk >= 
                                       1, 1, 0)

# %%
merge_crash_all_grouped2 = merge_crash_all.groupby('TICKER')\
                            [['VOL', 'PRC']]\
                           .resample('1Y').mean().reset_index()
merge_grouped[['VOL', 'PRC']] = merge_crash_all_grouped2[['VOL', 'PRC']]

# %%
merge_grouped[['ncskew','duvol']].corr()
# Out:
#           ncskew     duvol
# ncskew  1.000000  0.909937
# duvol   0.909937  1.000000

# %% [markdown]
# ## Balance Sheet Data

# %%
bs = pd.read_csv('bs_v.3.csv')
bs['Date'] = pd.to_datetime(bs.datadate, format='%Y%m%d')
bs['annual_date'] = bs['Date'].dt.year

# %%
bs['RoA'] = bs['ni'] / bs['at']
bs['leverage'] = bs['lt'] / bs['at']

# %%
merge_grouped['annual_date'] = merge_grouped['date'].dt.year
bs['TICKER'] = bs.tic
del bs['tic']

# %%
merge_ret_bs = pd.merge(bs, merge_grouped,
                        on=['TICKER', 'annual_date'])

# %%
merge_ret_bs2 = merge_ret_bs.set_index('Date')
merge_ret_bs2 = merge_ret_bs2.groupby('TICKER').resample('Y').mean()
merge_ret_bs2.reset_index(inplace=True)

# %%
merge_ret_bs2['vol_csho_diff'] = (merge_ret_bs2.groupby('TICKER')
                                  ['VOL'].shift(-1) / 
                                  merge_ret_bs2.groupby('TICKER')
                                  ['csho'].shift(-1))
merge_ret_bs2['dturn1'] = merge_ret_bs2['VOL'] / merge_ret_bs2['csho']
merge_ret_bs2['dturn'] = merge_ret_bs2['vol_csho_diff'] - \
                         merge_ret_bs2['dturn1']

# %%
merge_ret_bs2['p/e'] = merge_ret_bs2['PRC'] / merge_ret_bs2['ni']
merge_ret_bs2['turnover_rate'] = merge_ret_bs2['VOL'] / \
                                 merge_ret_bs2['csho']
merge_ret_bs2['equity_share'] = merge_ret_bs2['ceq'] / \
                                (merge_ret_bs2['ceq'] +
                                 merge_ret_bs2['dt'])
merge_ret_bs2['firm_size'] = np.log(merge_ret_bs2['at'])
merge_ret_bs2['cefd'] = (((merge_ret_bs2['at'] -
                           merge_ret_bs2['lt']) / merge_ret_bs2['csho']) - 
                           merge_ret_bs2['PRC']) / (merge_ret_bs2['at'] - 
                           merge_ret_bs2['lt']) / merge_ret_bs2['csho']

# %%
merge_ret_bs2 = merge_ret_bs2.set_index('Date')
merge_ret_bs2['buying_volume'] = merge_ret_bs2['VOL'] * \
                                 (merge_ret_bs2['PRC'] - 
                                  merge_ret_bs2['BIDLO']) / \
                                 (merge_ret_bs2['ASKHI'] - 
                                  merge_ret_bs2['BIDLO'])
merge_ret_bs2['selling_volume'] = merge_ret_bs2['VOL'] * \
                                  (merge_ret_bs2['ASKHI'] - 
                                   merge_ret_bs2['PRC']) / \
                                  (merge_ret_bs2['ASKHI'] - 
                                   merge_ret_bs2['BIDLO'])
buying_volume = merge_ret_bs2.groupby('TICKER')['buying_volume'] \
                .resample('Y').sum().reset_index()
selling_volume = merge_ret_bs2.groupby('TICKER')['selling_volume'] \
                .resample('Y').sum().reset_index()
del buying_volume['TICKER']
del buying_volume['Date']

# %%
buy_sel_vol = pd.concat([buying_volume,selling_volume], axis=1)
buy_sel_vol['bsi'] = (buy_sel_vol.buying_volume - 
                      buy_sel_vol.selling_volume) / \
                     (buy_sel_vol.buying_volume + 
                      buy_sel_vol.selling_volume)

# %%
merge_ret_bs2 = merge_ret_bs2.reset_index()
merge_ret_bs2 = pd.merge(buy_sel_vol ,merge_ret_bs2,
                         on=['TICKER', 'Date'])

# %% [markdown]
# ## Firm Sentiment via PCA

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
firm_sentiment = merge_ret_bs2[['p/e', 'turnover_rate',
                                'equity_share', 'cefd',
                                'leverage', 'bsi']]
firm_sentiment = firm_sentiment.apply(lambda x: x.fillna(x.mean()),
                                      axis=0)

# %%
firm_sentiment_std = StandardScaler().fit_transform(firm_sentiment)
pca = PCA(n_components=6)
pca_market_sentiment = pca.fit_transform(firm_sentiment_std)
print('Explained Variance Ratios per Component are:\n {}'\
      .format(pca.explained_variance_ratio_))
# Out:
# Explained Variance Ratios per Component are:
#  [0.35828322 0.2752777  0.15343653 0.12206041 0.06681776 0.02412438]

# %%
loadings_1 = pd.DataFrame(pca.components_.T * 
                          np.sqrt(pca.explained_variance_), 
                          columns=['PC1', 'PC2', 'PC3',
                                   'PC4', 'PC5', 'PC6'],
                          index=firm_sentiment.columns)
loadings_1
# Out:
#                     PC1       PC2       PC3       PC4       PC5       PC6
# p/e           -0.250786  0.326182  0.911665  0.056323  0.000583  0.021730
# turnover_rate -0.101554  0.854432 -0.197381  0.201749  0.428911 -0.008421
# equity_share  -0.913620 -0.162406 -0.133783  0.224513 -0.031672  0.271443
# cefd           0.639570 -0.118671  0.038422  0.754467 -0.100176  0.014146
# leverage       0.917298  0.098311  0.068633 -0.264369  0.089224  0.265335
# bsi            0.006731  0.878526 -0.173740 -0.044127 -0.446735  0.022520

# %%
df_loading1 = pd.DataFrame(loadings_1.mean(axis=1))# <3> 
df_loading1
# Out:
#                       0
# p/e            0.177616
# turnover_rate  0.196289
# equity_share  -0.124254
# cefd           0.204626
# leverage       0.195739
# bsi            0.040529

# %%
firm_sentiment = pd.DataFrame(np.dot(pca_market_sentiment,
                                     np.array(df_loading1)))
merge_ret_bs2['firm_sent'] = firm_sentiment

# %% [markdown]
# ## Panel Data Application

# %%
merge_ret_bs2['log_size'] = np.log(merge_ret_bs2['at'])

# %%
merge_ret_bs2.set_index(['TICKER', 'Date'], inplace=True)

# %%
X = (merge_ret_bs2[['log_size', 'rect', 'ppegt', 'dturn',
                'ncskew', 'residuals', 'RoA', 'annual_std',
                'firm_sent']]).shift(1)
X['neg_outliers'] = merge_ret_bs2['neg_outliers']

# %%
from pyeconometrics.panel_discrete_models import FixedEffectPanelModel
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
FE_ML = FixedEffectPanelModel()
FE_ML.fit(X, 'neg_outliers')
FE_ML.summary()
# Out:
# ================================================================================
# Dep. Variable:                      neg_outliers   Pseudo R-squ.:        0.08864
# Model:                 Panel Fixed Effects Logit   Log-Likelihood:       -83.721
# Method:                                      MLE   LL-Null:              -91.864
# No. Observations:                            193   LLR p-value:            0.092
# Df Model:                                      9
# Converged:                                  True
# ================================================================================
#                               coef  std err        t    P>|t| [95.0% Conf. Int.]
# --------------------------------------------------------------------------------
# _cons                     -2.2919    1.082   -2.118    0.017    -4.412    -0.171
# log_size                   0.1665    0.088    1.888    0.029    -0.006     0.339
# rect                      -0.0000    0.000   -3.855    0.000    -0.000    -0.000
# ppegt                     -0.0000    0.000   -0.612    0.270    -0.000     0.000
# dturn                      0.0003    0.000    7.744    0.000     0.000     0.000
# ncskew                    -0.1941    0.089   -2.187    0.014    -0.368    -0.020
# residuals                 -0.4191    1.705   -0.246    0.403    -3.760     2.922
# RoA                        1.4065    1.070    1.315    0.094    -0.690     3.503
# annual_std                 1.7581    0.547    3.212    0.001     0.685     2.831
# firm_sent                  0.5816    0.150    3.875    0.000     0.287     0.876
# --------------------------------------------------------------------------------

# %%
del X['neg_outliers']
X['crash_risk'] = merge_ret_bs2['crash_risk']

# %%
FE_crash = FixedEffectPanelModel()
FE_crash.fit(X, 'crash_risk')
FE_crash.summary()
# Out:
# ================================================================================
# Dep. Variable:                        crash_risk   Pseudo R-squ.:        0.05386
# Model:                 Panel Fixed Effects Logit   Log-Likelihood:       -55.603
# Method:                                      MLE   LL-Null:              -58.769
# No. Observations:                            193   LLR p-value:            0.787
# Df Model:                                      9
# Converged:                                  True
# ================================================================================
#                               coef  std err        t    P>|t| [95.0% Conf. Int.]
# --------------------------------------------------------------------------------
# _cons                     -3.1669    1.154   -2.744    0.003    -5.429    -0.905
# log_size                   0.1993    0.094    2.114    0.017     0.015     0.384
# rect                      -0.0000    0.000   -1.846    0.032    -0.000     0.000
# ppegt                     -0.0000    0.000   -0.643    0.260    -0.000     0.000
# dturn                      0.0001    0.000    2.908    0.002     0.000     0.000
# ncskew                     0.3736    0.114    3.265    0.001     0.149     0.598
# residuals                  3.3484    2.064    1.623    0.052    -0.696     7.393
# RoA                        2.4772    1.259    1.968    0.025     0.010     4.944
# annual_std                 2.4124    0.657    3.669    0.000     1.124     3.701
# firm_sent                 -0.0006    0.164   -0.004    0.499    -0.323     0.321
# --------------------------------------------------------------------------------
